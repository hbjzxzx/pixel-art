# %%
import core.hanlde_image as handle_image
import core.palette as palette
import io

# %%
with open('test2.jpg', 'rb') as f:
    image_buf = io.BytesIO(f.read())

# %%
image, format = handle_image.create_image_from_bytes(image_buf)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=900x1200>

# %%
small_image = handle_image.resize_image(image, (100, 100))

# %%
small_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
tiles, tttt = handle_image.split_image_into_tiles(small_image, (2, 2), palette.mardPalette)

# %%
tttt
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
len(tiles)
# Out:
# 2500

# %%
handle_image.preview_tiles(tiles, (50, 50), (30, 30), palette.mardPalette)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x1500>
